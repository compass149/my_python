# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import json
import urllib.request
client_id = "twf9t32hX6dHhrzVza3t"
client_secret = "5cpTnSNQMG"
encText = urllib.parse.quote("여행")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url) #url로 request 객체 생성
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)  #urlopen : urllib안에 있는 것
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    res_body=json.loads(response_body.decode('utf-8'))
    # print(res_body)
    items=res_body['items']
    for item in items:
        print('title:',item['title'])
        print('description:', item['description'])
        
else:
    print("Error Code:" + rescode)
# Out:
# title: 호주 역대급 입국심사 후기(퍼스<b>여행</b>)
# description: #서호주<b>여행</b> #퍼스<b>여행</b> 전자여권이라 그냥 스캔하고 들어갈 수도 있었지만 도장 찍으려고 줄 섰다가 ㅋㅋ 도장은 못 받고 질문세례만 받았다. 그냥 전자여권으로 전자입국하자… 지금까지 63개국 <b>여행</b>했고...
# title: 타이베이<b>여행</b> 3
# description: <b>여행</b>일기 8월달안에 다 쓰려고 했는데 어느새 9월이구만유 세번째날은 단수이 가는날 2024.08.07 눈깔... 안더웠다 <b>여행</b>할때 비가 거의 안와서 습도가 낮아서 그런듯 다행쓰 예전에 왔을때 날씨가 엄청 흐렸는데도...
# title: 괌 <b>여행</b> 일정 패키지 구매 괌 <b>여행</b> 경비 절약
# description: 며칠 전 다녀온 괌 <b>여행</b> 일정 모든 순간이 저에게는 특별한 추억이 되었습니다 역시 <b>여행</b>은 미리 준비해야 가격도 저렴하고 여러 가지 혜택을 받을 수 있는데요 여러분들도 괌 플레이를 통해서 숙소부터 관광지...
# title: 태국 코사무이 <b>여행</b> 맛집 Kawin's Kitchen
# description: ' 지금도 떠올리면 럭셔리라는 단어가 가장 먼저 떠오르는 태국 코사무이 <b>여행</b>, 시작부터 과도하게... 태국 코사무이 <b>여행</b> 맛집 Kawin's Kichen 글/사진 : 에피 오늘 포스팅에서는 태국 코사무이 <b>여행</b> 중 다녀왔던...
# title: (<b>여행</b> 기록)  밴프&amp;밴쿠버 <b>여행</b> 1-2일차
# description: 시간은 참 빠르다 벌써 언제 다녀왔나 싶게 <b>여행</b>을 마무리한지 이 주일이 지나가고 있다 정리를 해놔야 할 것 같다 이번 <b>여행</b>이 길어서 정리하는데도 한참 걸릴 것 같은데 일단 시작부터 해본다 6개월 전부터...
# title: 괌<b>여행</b>비용 호텔 일정 준비 팁 공유
# ...

# %%
encText = urllib.parse.quote("여행")
node='news'
start=1
display=100

base = 'https://openapi.naver.com/v1/search'
node='/%s.json'%(node)
parameters='?query=%s&start=%s&display=%s'%(encText, start, display)
url=base+node+parameters
print(url)
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url) #url로 request 객체 생성
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)  #urlopen : urllib안에 있는 것
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    res_body=json.loads(response_body.decode('utf-8'))
    # print(res_body)
    items=res_body['items']
    print(len(items))
    descriptStr=''
    for item in items:
        print('title:',item['title'])
        print('description:', item['description'])
        descriptStr+=item['description']
        
else:
    print("Error Code:" + rescode)
# Out:
# https://openapi.naver.com/v1/search/news.json?query=%EC%97%AC%ED%96%89&start=1&display=100
# 100
# title: “환불되면 입금하세요”...예약 강제 취소된 고객 감동시킨 제주 호텔...
# description: 호텔은 7월27일 이후인 여름 성수기에 <b>여행</b>·숙박 플랫폼 야놀자에서 티몬·위메프를 통해 판매된 호텔 예약 건이 일괄 취소된다고 통보받자 내부 협의를 통해 환불 여부와 관계없이 원래 <b>여행</b> 일정에 맞춰 전면 재예약...
# title: 신한은행, 해외<b>여행</b> 고객 대상 'SOL트래블라운지에서 환전했CU' 이벤트 ...
# description: &quot; 신한은행(은행장 정상혁)은 가을을 맞아 해외<b>여행</b>을 떠나는 고객들을 대상으로 'SOL트래블라운지에서... 신한은행 관계자는 &quot;향후 'SOL트래블라운지'와 '외화 ATM'을 확대 배치해 고객의 <b>여행</b> 여정에 동반자가...
# title: 강원관광재단, '강원 디엠제트(DMZ) 힐링 숲길 걷기' 개최
# description: 강원 최전방 비무장지대 트레킹 행사로 순수한 가을 단풍<b>여행</b> 만끽 최성현 대표 &quot;접경지역 관광 활성화와 누구나 찾는 특별한 <b>여행</b> 만들겠다&quot; 아주경제=춘천=강대웅·윤중국 기자 yjk@ajunews.com [사진=강원관광재단]...
# title: 안성시, 2024 남사당 바우덕이 축제 화려하게 개막
# description: 행복과 웃음이 가득한 시간을 보내시길 바란다&quot;며, &quot;우리 시가 열심히 준비한 바우덕이 축제가 싱그러운 가을 <b>여행</b>의 잊을 수 없는 삶의 한 페이지로 기억될 수 있기를 기원한다&quot;고 말했다. 이코노미퀸 / 사진 안성시
# title: &quot;영남아 놀자, 호남아 어서와~!&quot; 2024 동서화합 영호남 문화예술관광박...
# ...

# %%
from konlpy.tag import *
komoran = Komoran()
nouns = komoran.nouns(descriptStr)
nouns
# Out:
# ['호텔',
#  '월',
#  '일',
#  '이후',
#  '여름',
#  '성수기',
#  '여행',
#  '숙박',
#  '플랫폼',
#  '야',
#  '티몬',
#  '위메프',
#  '판매',
#  '호텔',
#  '예약',
#  '건',
#  '일괄',
#  '취소',
#  '통보',
#  '내부',
#  '협의',
#  '환불',
#  '여부',
#  '원래',
#  '여행',
#  '일정',
#  '전면',
#  '예약',
#  '신한은행',
#  '은행장',
#  '정상',
#  '혁',
#  '가을',
#  '해외',
#  '여행',
#  '고객',
#  '대상',
#  '트래블',
#  '라운지',
#  '신한은행',
#  '관계자',
#  '향후',
#  '트래블',
#  '라운지',
#  '외화',
#  '확대',
#  '배치',
#  '고객',
#  '여행',
#  '여정',
#  '동반자',
#  '강원',
#  '최',
#  '전방',
#  '비무장지대',
#  '트레킹',
#  '행사',
#  '순수',
#  '단풍',
#  '여행',
#  '만끽',
#  '최성현',
#  '대표',
#  '접경',
#  '지역',
#  '관광',
#  '활성',
#  '여행',
#  '기자',
#  '.com',
#  '사진',
#  '강원',
#  '관광',
#  '재단',
#  '행복',
#  '웃음',
#  '시간',
#  '우리',
#  '시가',
#  '준비',
#  '바우덕이',
#  '축제',
#  '여행',
#  '수',
#  '삶',
#  '페이지',
#  '기억',
#  '수',
#  '기원',
#  '말',
#  '코',
#  '노미',
#  '퀸',
#  '사진',
#  '안성시',
#  '일',
#  '경북',
#  '도청',
#  '안',
#  '민관',
#  '출정식',
#  '카메라',
#  '여행',
#  '가방',
#  '선글라스',
#  '무장',
#  '관광',
#  '산업',
#  '종사자',
# ...

# %%
from collections import Counter
c = Counter(nouns)
c1=c.most_common(100)

# %%
wordInfo=dict()
for t, c in c1:
    if len(t) > 1:
        wordInfo[t]=c
wordInfo
# Out:
# {'여행': 168,
#  '고객': 34,
#  '해외': 28,
#  '신한은행': 27,
#  '가을': 24,
#  '대상': 20,
#  '트래블': 20,
#  '라운지': 20,
#  '제공': 17,
#  '사진': 14,
#  '중국': 13,
#  '진행': 13,
#  '서비스': 12,
#  '이벤트': 12,
#  '관광': 11,
#  '축제': 11,
#  '문화': 11,
#  '여정': 10,
#  '동반자': 10,
#  '지역': 10,
#  '외환': 9,
#  '이번': 9,
#  '기자': 8,
#  '국내': 8,
#  '시즌': 8,
#  '익산': 8,
#  '예약': 7,
#  '시간': 7,
#  '시작': 7,
#  '활동': 7,
#  '뱅크': 7,
#  '최근': 7,
#  '김동선': 7,
#  '은행장': 6,
#  '정상': 6,
#  '배치': 6,
#  '대표': 6,
#  '포함': 6,
#  '청소년': 6,
#  '체험': 6,
#  '영상': 6,
#  '지원': 6,
#  '전국': 6,
#  '상품': 6,
#  '부영': 6,
#  '제주': 6,
#  '호텔': 5,
#  '단풍': 5,
#  '준비': 5,
#  '기억': 5,
#  '기원': 5,
#  '안성시': 5,
#  '화장실': 5,
#  '예산': 5,
#  '일본': 5,
#  '주제': 5,
#  '관광객': 5,
#  '디지털': 5,
#  '대한민국': 5,
#  '크리에이터': 5,
#  '사랑': 5,
#  '신한': 5,
#  '넷플릭스': 5,
#  '그룹': 5,
#  '매력': 5,
#  '환전': 5,
#  '연천': 5,
#  '고대산': 5,
#  '에피그램': 5,
#  '원래': 4,
#  '확대': 4,
#  '강원': 4,
#  '바우덕이': 4,
#  '페이지': 4,
#  '황산': 4,
#  '모습': 4,
#  '할머니': 4,
#  '한편': 4,
#  '경험': 4,
# ...

# %%
import pytagcloud
taglist=pytagcloud.make_tags(dict(wordInfo).items(), maxsize=80)
taglist
# Out:
# [{'color': (74, 78, 92), 'size': 81, 'tag': '여행'},
#  {'color': (44, 14, 135), 'size': 24, 'tag': '고객'},
#  {'color': (117, 181, 129), 'size': 21, 'tag': '해외'},
#  {'color': (207, 147, 171), 'size': 21, 'tag': '신한은행'},
#  {'color': (85, 58, 177), 'size': 19, 'tag': '가을'},
#  {'color': (167, 79, 209), 'size': 17, 'tag': '대상'},
#  {'color': (159, 183, 15), 'size': 17, 'tag': '트래블'},
#  {'color': (157, 51, 93), 'size': 17, 'tag': '라운지'},
#  {'color': (204, 84, 217), 'size': 15, 'tag': '제공'},
#  {'color': (214, 62, 132), 'size': 13, 'tag': '사진'},
#  {'color': (215, 106, 128), 'size': 13, 'tag': '중국'},
#  {'color': (105, 177, 67), 'size': 13, 'tag': '진행'},
#  {'color': (63, 176, 164), 'size': 12, 'tag': '서비스'},
#  {'color': (217, 59, 83), 'size': 12, 'tag': '이벤트'},
#  {'color': (206, 76, 24), 'size': 11, 'tag': '관광'},
#  {'color': (208, 70, 149), 'size': 11, 'tag': '축제'},
#  {'color': (25, 133, 125), 'size': 11, 'tag': '문화'},
#  {'color': (51, 68, 54), 'size': 11, 'tag': '여정'},
# ...

# %%
pytagcloud.create_tag_image(taglist,'./pytagcloud.png', size=(600, 400), fontname='Korean2', rectangular=True)

# %%
from konlpy.tag import *
hannanum = Hannanum()
kkma = Kkma()
komoran = Komoran()
okt = Okt()

# %%
import pandas as pd
tagsets = pd.DataFrame()
N = 67
tagsets["한나눔-기호"] = list(hannanum.tagset.keys())+list("*"*(N - len(hannanum.tagset)))
tagsets["한나눔-품사"] = list(hannanum.tagset.values())+list("*"*(N - len(hannanum.tagset)))
tagsets["Kkma-기호"] = list(kkma.tagset.keys())+list("*"*(N - len(kkma.tagset)))
tagsets["Kkma-품사"] = list(kkma.tagset.values())+list("*"*(N - len(kkma.tagset)))
tagsets["코모란-기호"] = list(komoran.tagset.keys())+list("*"*(N - len(komoran.tagset)))
tagsets["코모란-품사"] = list(komoran.tagset.values())+list("*"*(N - len(komoran.tagset)))
tagsets["OKT-기호"] = list(okt.tagset.keys())+list("*"*(N - len(okt.tagset)))
tagsets["OKT-품사"] = list(okt.tagset.values())+list("*"*(N - len(okt.tagset)))
tagsets
# Out:
#    한나눔-기호 한나눔-품사 Kkma-기호     Kkma-품사 코모란-기호     코모란-품사       OKT-기호 OKT-품사
# 0       E     어미      EC       연결 어미     EC      연결 어미    Adjective    형용사
# 1      EC  연결 어미     ECD   의존적 연결 어미     EF      종결 어미       Adverb     부사
# 2      EF  종결 어미     ECE    대등 연결 어미     EP      선어말어미        Alpha    알파벳
# 3      EP  선어말어미     ECS   보조적 연결 어미    ETM  관형형 전성 어미  Conjunction    접속사
# 4      ET  전성 어미      EF       종결 어미    ETN  명사형 전성 어미   Determiner    관형사
# ..    ...    ...     ...         ...    ...        ...          ...    ...
# 62      *      *     XPV      용언 접두사      *          *            *      *
# 63      *      *      XR          어근      *          *            *      *
# 64      *      *     XSA  형용사 파생 접미사      *          *            *      *
# 65      *      *     XSN    명사파생 접미사      *          *            *      *
# 66      *      *     XSV   동사 파생 접미사      *          *            *      *
#
# [67 rows x 8 columns]

# %%
from konlpy.corpus import kolaw
kolaw.fileids()
# Out:
# ['constitution.txt']

# %%
c = kolaw.open('constitution.txt').read()
print(c[:40])
# Out:
# 대한민국헌법
#
# 유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로

# %%
okt.nouns(c[:40])
# Out:
# ['대한민국', '헌법', '유구', '역사', '전통', '우리', '국민', '운동']

# %%
from nltk import Text
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager, rc

font_path = "C:/Windows/fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
matplotlib.rc('font', family= font_name)

kolaw = Text(okt.nouns(c), name="kolaw")
kolaw.plot(30)
plt.show()

# %%
fd=kolaw.vocab()
print(type(fd))
print(fd.most_common(20))
# Out:
# <class 'nltk.probability.FreqDist'>
# [('제', 175), ('법률', 127), ('정', 89), ('수', 88), ('대통령', 83), ('국가', 73), ('국회', 68), ('국민', 61), ('관', 58), ('때', 55), ('헌법', 53), ('그', 47), ('이', 38), ('모든', 37), ('바', 37), ('위', 36), ('기타', 26), ('및', 25), ('사항', 23), ('권리', 21)]

# %%
from wordcloud import WordCloud
font_path = 'C:/Windows/Fonts/HMKMRHD.TTF'

wc = WordCloud(width=1000, height =600, background_color="white", font_path=font_path)
keywords={'이것':5, '예문':30, '단어': 15}
plt.imshow(wc.generate_from_frequencies(keywords))
#plt.imshow(wc.generate_From_frequencies(kolaw.vocab()))
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
wc = WordCloud(width=800, height=600, background_color='white', font_path=font_path)
plt.imshow(wc.generate_from_frequencies(kolaw.vocab()))
plt.axis('off')
plt.savefig('data/wordcloud.png')
plt.show()

# %%
file = open('/data/result.txt', 'r')
data=file.read()
print(data)
# Out:
# CHAPTER I
#
# "Well, Prince, so Genoa and Lucca are now just family estates of
# theBuonapartes. But I warn you, if you don't tell me that this
# means war,if you still try to defend the infamies and horrors
# perpetrated bythat Antichrist- I really believe he is Antichrist- I will
# havenothing more to do with you and you are no longer my friend,
# no longermy 'faithful slave,' as you call yourself! But how do you
# do? I seeI have frightened you- sit down and tell me all the news."
#
# It was in July, 1805, and the speaker was the well-known
# AnnaPavlovna Scherer, maid of honor and favorite of the
# Empress MaryaFedorovna. With these words she greeted Prince
# Vasili Kuragin, a manof high rank and importance, who was the
# first to arrive at herreception. Anna Pavlovna had had a cough for
# some days. She was, asshe said, suffering from la grippe; grippe
# being then a new word inSt. Petersburg, used only by the elite.
#
# All her invitations without exception, written in French,
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome()
driver.implicitly_wait(3)
driver.get("https://www.istarbucks.co.kr/store/store_map.do")
time.sleep(2)
loca = driver.find_element(By.CLASS_NAME,"loca_search")
loca.click()
f_link=driver.find_element(By.CSS_SELECTOR,"div.loca_step1_cont > ul>li:nth-child(1)>a")
f_link.click()
time.sleep(2)
s_link=driver.find_element(By.CSS_SELECTOR,"#mCSB_2_container > ul>li:nth-child(1)>a")
s_link.click()
time.sleep(2)
shopList=driver.find_elements(By.CSS_SELECTOR,"#mCSB_3_container > ul>li")

temp_list = []
time.sleep(3)
count=0
total=len(shopList)
print(total)
# Out:
# 623

# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.implicitly_wait(5)
driver.get("http://www.yes24.com/Product/goods/40936880")
time.sleep(2)

try:
    readLinks = driver.find_elements(By.CSS_SELECTOR,'#infoset_reviewContentList div.reviewInfoBot.crop > a')
    for readlink in readLinks:
        readlink.click()
        time.sleep(1)
        
    reviewList=driver.find_elements(By.CSS_SELECTOR,'#infoset_reviewContentList> div.reviewInfoGrp.InkExtend.infoMoreSubOn>div.reviewInfoBot.origin> div.review_cont')
    temp_list=[]
    time.sleep(3)
    
    for review in reviewList:
        temp_list.append(review.text)
    print(temp_list)
    stopFlag=False
    while True:
        for n in range(4,13):
            linkurl ='#infoset_reviewContentList > div.review_sort.sortBot > div.review_sortLft > div > a:nth-child('+str(n)+')'
            linkNum = driver.find_element(By.CSS_SELECTOR,'linkurl')
            linkNum.click()
            time.sleep(3)
            readLinks = driver.find_elements(By.CSS_SELECTOR,'#infoset_reviewContentList div.reviewInfoBot.crop > a')
            
            for readlink in readLinks:
                readlink.click()
                #driver.execute_script("arguments[0].click();", readlink)
                time.sleep(3)
                
            reviewList = driver.find_elements(By.CSS_SELECTOR,'#infoset_reviewContentList > div.reviewInfoGrp.InkExtend.infoMoreSubOn>div.reviewInfoBot.origin>div.review_cont')
            time.sleep(2)
            
            for review in reviewList:
                temp_list.append(review.text)
                
            if len(reviewList) < 5:
                stopFlag = True
                break
            
        if stopFlag == True:
            break
        nextPage = '#infoset_reviewContentList > div.review_sort.sortBot > div.review_sortLft>div>a.bgYUI.next'
        linkNum = driver.find_element(By.CSS_SELECTOR,'nextPage')
        linkNum.click()
        time.sleep(1)
        
except Exception as ex:
    print("오류발생 :" +ex)
finally:
    driver.quit()
    
for item in temp_list:
    print(item)
    
wfile = open("C:/data/yes24file.txt","w")
wfile.writelines(temp_list)
wfile.close()
# Out:
# []
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[3], line 27
#      26 linkurl ='#infoset_reviewContentList > div.review_sort.sortBot > div.review_sortLft > div > a:nth-child('+str(n)+')'
# ---> 27 linkNum = driver.find_element(By.CSS_SELECTOR,'linkurl')
#      28 linkNum.click()
#
# File c:\Users\dhdms\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\dhdms\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
# ...
